# %%
import numpy as np 
import pandas as pd 
import os
import cv2
import matplotlib.pyplot as plt

Image_folder = 'Y:\coskun-lab\Thomas\Mayar-Data\Image'
Mask_folder = 'Y:\coskun-lab\Thomas\Mayar-Data\Mask'

# %matplotlib inline

# %%
filename = 'ROI005 Area 1DisTon1_Cell_Mask.tiff'
img = cv2.imread(os.path.join(filename),-1)

vals = np.linspace(0,1,45185)
np.random.shuffle(vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.gnuplot2(vals))

plt.figure(figsize=(20,20))
plt.imshow(img, cmap = cmap)
plt.axis('off')
# Out:
# (-0.5, 2499.5, 2499.5, -0.5)

# %%
img.max()
# Out:
# 45185
